# %% [markdown]
# # Seleniumをインポートする。

# %%
# !pip install selenium
# Out:
# ...
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# ...

# %%
import time

from PIL import Image
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# # chromedriverの位置を確認する

# %%
# !ls /Users/ozawaatsushi/Applications/
# Out:
# Kindle       chromedriver

# %% [markdown]
# # driverを作る

# %%
driver = webdriver.Chrome(
    executable_path="/Users/ozawaatsushi/Applications/chromedriver"
)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-7-b0af52cc2d21> in <module>
# ----> 1 driver = webdriver.Chrome(executable_path="/Users/ozawaatsushi/Applications/chromedriver")
#
# ~/anaconda3/envs/work/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ~/anaconda3/envs/work/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
# ...

# %% [markdown]
# # Chromeのバージョンを確認、これと一致するchrome driverをインストールし直す。

# %%
path = "/Users/ozawaatsushi/Desktop/google_chrome_version.png"
img = Image.open(path)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2536x1254 at 0x7FF68FE50790>

# %%
# !ls /Users/ozawaatsushi/Applications/
# Out:
# Kindle                     chromedriver_92_0_4515_107
# chromedriver

# %%
driver = webdriver.Chrome(
    executable_path="/Users/ozawaatsushi/Applications/chromedriver_92_0_4515_107"
)

# %% [markdown]
# # URLを開く

# %%
driver.get(
    "https://access.line.me/oauth2/v2.1/login?loginState=fStlrdVKY81l9CedFPdKye&loginChannelId=1655651234&returnUri=%2Foauth2%2Fv2.1%2Fauthorize%2Fconsent%3Fmax_age%3D3600%26scope%3Dprofile%2Bopenid%26response_type%3Dcode%26state%3D86f6249eb8b5ae9ce2b81343c16ef87c6699d4a2f2aef7840330f89715c1965d%26redirect_uri%3Dhttps%253A%252F%252Fsso.line-sec.co.jp%252Fauth%252Fline-login%252Fauthorize%253FssoState%253D86f6249eb8b5ae9ce2b81343c16ef87c6699d4a2f2aef7840330f89715c1965d%2526serviceId%253Db1af7520-c1a5-e0b1-c727-aa93891c41ac%2526redirectUrl%253D%25252F%26client_id%3D1655651234#/"
)

# %%
# 3秒待機
time.sleep(3)

# %% [markdown]
# # ログインIDを入力

# %%
login_id = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[2]/div/form/fieldset/div[1]/input')
mail = "noap3b69n@gmail.com"
login_id.send_keys(mail)

# %% [markdown]
# # ログインパスワードを入力

# %%
login_pass = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[2]/div/form/fieldset/div[2]/input')
password = "8423240712no3b"
login_pass.send_keys(password)

# %% [markdown]
# # ログインボタンをクリックする

# %%
login_btn = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[2]/div/form/fieldset/div[3]/button')
login_btn.click()
